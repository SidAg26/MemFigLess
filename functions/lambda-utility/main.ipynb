# %%
from log_collector import LogCollector as lc
from datetime import datetime

# %%
logs = lc(function_name='workbench-matmul', file_name='abc', 
          start_time=datetime(year=2024, month=1, day=1), 
          end_time=datetime(year=2024, month=1, day=17))

# %%
logs.get_cloudwatch_logs()
# Out:
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# FOUND NEXT TOKEN
# ...

# %%
print(logs.get_response_stream())
# Out:
# {'events': [], 'nextForwardToken': 'f/38032796978535971824482834113800839071029698075033600000/s', 'nextBackwardToken': 'b/38032796978535971824482834113800839071029698075033600000/s', 'ResponseMetadata': {'RequestId': '8aa13351-b6cd-4448-a883-7411308444f8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '8aa13351-b6cd-4448-a883-7411308444f8', 'content-type': 'application/x-amz-json-1.1', 'content-length': '178', 'date': 'Thu, 18 Jan 2024 08:14:27 GMT'}, 'RetryAttempts': 0}}
